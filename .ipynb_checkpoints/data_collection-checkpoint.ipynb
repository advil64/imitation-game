: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1816] Ignoring visible gpu device (device: 0, name: GeForce GT 630, pci bus id: 0000:02:00.0, compute capability: 3.0) with Cuda compute capability 3.0. The minimum required Cuda capability is 3.5.
# 2021-12-14 22:29:15.626806: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1816] Ignoring visible gpu device (device: 0, name: GeForce GT 630, pci bus id: 0000:02:00.0, compute capability: 3.0) with Cuda compute capability 3.0. The minimum required Cuda capability is 3.5.
# 2021-12-14 22:29:15.626841: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1816] Ignoring visible gpu device (device: 0, name: GeForce GT 630, pci bus id: 0000:02:00.0, compute capability: 3.0) with Cuda compute capability 3.0. The minimum required Cuda capability is 3.5.
# 2021-12-14 22:29:15.626901: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1816] Ignoring visible gpu device (device: 0, name: GeForce GT 630, pci bus id: 0000:02:00.0, compute capability: 3.0) with Cuda compute capability 3.0. The minimum required Cuda capability is 3.5.
# Traceback (most recent call last):
#   File "src/main_nn.py", line 5, in <module>
#     from agent_1_nn_sim import Agent_1 as agent_1_nn
#   File "/common/users/ac1771/imitation-game/src/agent_1_nn_sim.py", line 8, in <module>
#     tf.config.experimental.set_memory_growth(physical_devices[0], True)
# IndexError: list index out of range
# Traceback (most recent call last):
#   File "src/main_nn.py", line 5, in <module>
#     from agent_1_nn_sim import Agent_1 as agent_1_nn
#   File "/common/users/ac1771/imitation-game/src/agent_1_nn_sim.py", line 8, in <module>
#     tf.config.experimental.set_memory_growth(physical_devices[0], True)
# IndexError: list index out of range
# Traceback (most recent call last):
#   File "src/main_nn.py", line 5, in <module>
#     from agent_1_nn_sim import Agent_1 as agent_1_nn
#   File "/common/users/ac1771/imitation-game/src/agent_1_nn_sim.py", line 8, in <module>
#     tf.config.experimental.set_memory_growth(physical_devices[0], True)
# IndexError: list index out of range
# Traceback (most recent call last):
#   File "src/main_nn.py", line 5, in <module>
#     from agent_1_nn_sim import Agent_1 as agent_1_nn
#   File "/common/users/ac1771/imitation-game/src/agent_1_nn_sim.py", line 8, in <module>
#     tf.config.experimental.set_memory_growth(physical_devices[0], True)
# IndexError: list index out of range
# Traceback (most recent call last):
#   File "src/main_nn.py", line 5, in <module>
#     from agent_1_nn_sim import Agent_1 as agent_1_nn
#   File "/common/users/ac1771/imitation-game/src/agent_1_nn_sim.py", line 8, in <module>
#     tf.config.experimental.set_memory_growth(physical_devices[0], True)
# IndexError: list index out of range
# Process Process-2:
# Traceback (most recent call last):
# Process Process-1:
# Process Process-4:
# Process Process-3:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/tmp/ipykernel_1381097/516284570.py", line 5, in pri
#     if subprocess.check_call(command, cwd='/common/users/ac1771/imitation-game', shell=True):
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.8/subprocess.py", line 364, in check_call
#     raise CalledProcessError(retcode, cmd)
#   File "/tmp/ipykernel_1381097/516284570.py", line 5, in pri
#     if subprocess.check_call(command, cwd='/common/users/ac1771/imitation-game', shell=True):
# subprocess.CalledProcessError: Command 'python3 src/main_nn.py -d 50 -w results/agent_1 -p 0.3' returned non-zero exit status 1.
#   File "/usr/lib/python3.8/subprocess.py", line 364, in check_call
#     raise CalledProcessError(retcode, cmd)
# Process Process-5:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_1381097/516284570.py", line 5, in pri
#     if subprocess.check_call(command, cwd='/common/users/ac1771/imitation-game', shell=True):
# subprocess.CalledProcessError: Command 'python3 src/main_nn.py -d 50 -w results/agent_1 -p 0.3' returned non-zero exit status 1.
#   File "/usr/lib/python3.8/subprocess.py", line 364, in check_call
#     raise CalledProcessError(retcode, cmd)
# subprocess.CalledProcessError: Command 'python3 src/main_nn.py -d 50 -w results/agent_1 -p 0.3' returned non-zero exit status 1.
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/tmp/ipykernel_1381097/516284570.py", line 5, in pri
#     if subprocess.check_call(command, cwd='/common/users/ac1771/imitation-game', shell=True):
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_1381097/516284570.py", line 5, in pri
#     if subprocess.check_call(command, cwd='/common/users/ac1771/imitation-game', shell=True):
#   File "/usr/lib/python3.8/subprocess.py", line 364, in check_call
#     raise CalledProcessError(retcode, cmd)
#   File "/usr/lib/python3.8/subprocess.py", line 364, in check_call
#     raise CalledProcessError(retcode, cmd)
# subprocess.CalledProcessError: Command 'python3 src/main_nn.py -d 50 -w results/agent_1 -p 0.3' returned non-zero exit status 1.
# subprocess.CalledProcessError: Command 'python3 src/main_nn.py -d 50 -w results/agent_1 -p 0.3' returned non-zero exit status 1.

# %%
# Create new threads
for i in range(5):
  t = myThread(i, "thread_{}".format(i), i)
  t.start()

print("Exiting Main Thread")

# %%
# measure probability calculation efficiency
results_df = pd.DataFrame(columns = ['Processed Cells', 'Retries', 'Time', 'Examinations', 'Movements', 'Actions', 'Terrain'])
agents = ["Agent 6", "Agent 7", "Agent 8"]

for x in range(100):
  command = 'python main.py -d 50 -p 0.3'
  out = json.loads(str(check_output(command, cwd='/Users/naveenanyogeswaran/Desktop/School/probabilistic-sensing/src', shell=True)).lstrip("b'").rstrip("'").replace("\\n", ""))

  for i,a in enumerate(agents):
    results_df = results_df.append([{'Agent': i+6, 'Processed Cells': out[a]["processed"], 'Retries': out[a]["retries"], 'Time': out[a]["time"], 'Examinations': out[a]["examinations"], 'Movements': out[a]["movements"], 'Actions': out[a]["examinations"] + out[a]["movements"], 'Terrain': out[a]["terrain"]}], ignore_index=True)

results_df.head()

# %%
path = 'results/agent_1/{}'.format('thread_test')
command = 'python3 src/main_nn.py -d 50 -w {} -p 0.3'.format(path)
subprocess.check_call(command, cwd='/common/users/ac1771/imitation-game', shell=True)

# %%
print(mp.cpu_count())
