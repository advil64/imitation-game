W tensorflow/stream_executor/stream.cc:1455] attempting to perform BLAS operation using StreamExecutor without BLAS support
# 2021-12-15 01:06:47.786939: E tensorflow/stream_executor/cuda/cuda_blas.cc:226] failed to create cublas handle: CUBLAS_STATUS_NOT_INITIALIZED
# 2021-12-15 01:06:47.787029: E tensorflow/stream_executor/cuda/cuda_blas.cc:226] failed to create cublas handle: CUBLAS_STATUS_NOT_INITIALIZED
# 2021-12-15 01:06:47.787048: W tensorflow/stream_executor/stream.cc:1455] attempting to perform BLAS operation using StreamExecutor without BLAS support
# 2021-12-15 01:06:47.787811: E tensorflow/stream_executor/cuda/cuda_blas.cc:226] failed to create cublas handle: CUBLAS_STATUS_NOT_INITIALIZED
# 2021-12-15 01:06:47.788899: E tensorflow/stream_executor/cuda/cuda_blas.cc:226] failed to create cublas handle: CUBLAS_STATUS_NOT_INITIALIZED
# 2021-12-15 01:06:47.789603: E tensorflow/stream_executor/cuda/cuda_blas.cc:226] failed to create cublas handle: CUBLAS_STATUS_NOT_INITIALIZED
# 2021-12-15 01:06:47.791284: E tensorflow/stream_executor/cuda/cuda_blas.cc:226] failed to create cublas handle: CUBLAS_STATUS_NOT_INITIALIZED
# 2021-12-15 01:06:47.793111: E tensorflow/stream_executor/cuda/cuda_blas.cc:226] failed to create cublas handle: CUBLAS_STATUS_NOT_INITIALIZED
# 2021-12-15 01:06:47.794485: E tensorflow/stream_executor/cuda/cuda_blas.cc:226] failed to create cublas handle: CUBLAS_STATUS_NOT_INITIALIZED
# 2021-12-15 01:06:47.795987: E tensorflow/stream_executor/cuda/cuda_blas.cc:226] failed to create cublas handle: CUBLAS_STATUS_NOT_INITIALIZED
# 2021-12-15 01:06:47.796012: W tensorflow/stream_executor/stream.cc:1455] attempting to perform BLAS operation using StreamExecutor without BLAS support
# 2021-12-15 01:06:47.796253: E tensorflow/stream_executor/cuda/cuda_blas.cc:226] failed to create cublas handle: CUBLAS_STATUS_NOT_INITIALIZED
# 2021-12-15 01:06:47.797979: E tensorflow/stream_executor/cuda/cuda_blas.cc:226] failed to create cublas handle: CUBLAS_STATUS_NOT_INITIALIZED
# 2021-12-15 01:06:47.802591: E tensorflow/stream_executor/cuda/cuda_blas.cc:226] failed to create cublas handle: CUBLAS_STATUS_NOT_INITIALIZED
# 2021-12-15 01:06:47.802624: W tensorflow/stream_executor/stream.cc:1455] attempting to perform BLAS operation using StreamExecutor without BLAS support
# 2021-12-15 01:06:47.806433: E tensorflow/stream_executor/cuda/cuda_blas.cc:226] failed to create cublas handle: CUBLAS_STATUS_NOT_INITIALIZED
# 2021-12-15 01:06:47.806899: E tensorflow/stream_executor/cuda/cuda_blas.cc:226] failed to create cublas handle: CUBLAS_STATUS_NOT_INITIALIZED
# 2021-12-15 01:06:47.807767: E tensorflow/stream_executor/cuda/cuda_blas.cc:226] failed to create cublas handle: CUBLAS_STATUS_NOT_INITIALIZED
# 2021-12-15 01:06:47.810128: E tensorflow/stream_executor/cuda/cuda_blas.cc:226] failed to create cublas handle: CUBLAS_STATUS_NOT_INITIALIZED
# 2021-12-15 01:06:47.810151: W tensorflow/stream_executor/stream.cc:1455] attempting to perform BLAS operation using StreamExecutor without BLAS support
# 2021-12-15 01:06:47.814939: E tensorflow/stream_executor/cuda/cuda_blas.cc:226] failed to create cublas handle: CUBLAS_STATUS_NOT_INITIALIZED
# 2021-12-15 01:06:47.820959: E tensorflow/stream_executor/cuda/cuda_blas.cc:226] failed to create cublas handle: CUBLAS_STATUS_NOT_INITIALIZED
# 2021-12-15 01:06:47.829744: I tensorflow/stream_executor/stream.cc:1404] [stream=0x17825ec0,impl=0x4ae9910] did not wait for [stream=0x4aeafa0,impl=0x4ae97a0]
# 2021-12-15 01:06:47.829851: F tensorflow/core/common_runtime/gpu/gpu_util.cc:291] GPU->CPU Memcpy failed
# 2021-12-15 01:06:47.830711: I tensorflow/stream_executor/stream.cc:1404] [stream=0x18b12df0,impl=0x6127f60] did not wait for [stream=0x18a5afc0,impl=0x6128020]
# 2021-12-15 01:06:47.830829: F tensorflow/core/common_runtime/gpu/gpu_util.cc:291] GPU->CPU Memcpy failed
# 2021-12-15 01:06:47.830841: E tensorflow/stream_executor/cuda/cuda_blas.cc:226] failed to create cublas handle: CUBLAS_STATUS_NOT_INITIALIZED
# 2021-12-15 01:06:47.830864: W tensorflow/stream_executor/stream.cc:1455] attempting to perform BLAS operation using StreamExecutor without BLAS support
# 2021-12-15 01:06:47.831868: I tensorflow/stream_executor/stream.cc:1404] [stream=0x175d4540,impl=0x4f39ff0] did not wait for [stream=0x175d19e0,impl=0x4f3a290]
# 2021-12-15 01:06:47.831943: F tensorflow/core/common_runtime/gpu/gpu_util.cc:291] GPU->CPU Memcpy failed
# 2021-12-15 01:06:47.832533: I tensorflow/stream_executor/stream.cc:1404] [stream=0x18b0d010,impl=0x5de4390] did not wait for [stream=0x5de2ef0,impl=0x5de2710]
# 2021-12-15 01:06:47.832617: F tensorflow/core/common_runtime/gpu/gpu_util.cc:291] GPU->CPU Memcpy failed
# 2021-12-15 01:06:47.837104: I tensorflow/stream_executor/stream.cc:1404] [stream=0x1864cf30,impl=0x61fe130] did not wait for [stream=0x18234c80,impl=0x61fd080]
# 2021-12-15 01:06:47.837224: F tensorflow/core/common_runtime/gpu/gpu_util.cc:291] GPU->CPU Memcpy failed
# 2021-12-15 01:06:47.854893: I tensorflow/stream_executor/stream.cc:1404] [stream=0x182cf260,impl=0x5964cd0] did not wait for [stream=0x5965160,impl=0x5964d00]
# 2021-12-15 01:06:47.855013: F tensorflow/core/common_runtime/gpu/gpu_util.cc:291] GPU->CPU Memcpy failed
# 2021-12-15 01:06:47.857355: I tensorflow/stream_executor/stream.cc:1404] [stream=0x172c2190,impl=0x48fc6d0] did not wait for [stream=0x48fc260,impl=0x48fabd0]
# 2021-12-15 01:06:47.857442: F tensorflow/core/common_runtime/gpu/gpu_util.cc:291] GPU->CPU Memcpy failed
# 2021-12-15 01:06:47.876270: I tensorflow/stream_executor/stream.cc:1404] [stream=0x187baef0,impl=0x5974360] did not wait for [stream=0x185bf070,impl=0x5ab09c0]
# 2021-12-15 01:06:47.876367: F tensorflow/core/common_runtime/gpu/gpu_util.cc:291] GPU->CPU Memcpy failed
# Process Process-5:
# Process Process-3:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_2954464/516284570.py", line 5, in pri
#     if subprocess.check_call(command, cwd='/common/users/ac1771/imitation-game', shell=True):
#   File "/usr/lib/python3.8/subprocess.py", line 364, in check_call
#     raise CalledProcessError(retcode, cmd)
# subprocess.CalledProcessError: Command 'python3 src/main_nn.py -d 50 -w results/agent_1 -p 0.3' returned non-zero exit status 134.
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_2954464/516284570.py", line 5, in pri
#     if subprocess.check_call(command, cwd='/common/users/ac1771/imitation-game', shell=True):
#   File "/usr/lib/python3.8/subprocess.py", line 364, in check_call
#     raise CalledProcessError(retcode, cmd)
# subprocess.CalledProcessError: Command 'python3 src/main_nn.py -d 50 -w results/agent_1 -p 0.3' returned non-zero exit status 134.
# Process Process-6:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_2954464/516284570.py", line 5, in pri
#     if subprocess.check_call(command, cwd='/common/users/ac1771/imitation-game', shell=True):
#   File "/usr/lib/python3.8/subprocess.py", line 364, in check_call
#     raise CalledProcessError(retcode, cmd)
# subprocess.CalledProcessError: Command 'python3 src/main_nn.py -d 50 -w results/agent_1 -p 0.3' returned non-zero exit status 134.
# Process Process-8:
# Process Process-2:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_2954464/516284570.py", line 5, in pri
#     if subprocess.check_call(command, cwd='/common/users/ac1771/imitation-game', shell=True):
#   File "/usr/lib/python3.8/subprocess.py", line 364, in check_call
#     raise CalledProcessError(retcode, cmd)
# subprocess.CalledProcessError: Command 'python3 src/main_nn.py -d 50 -w results/agent_1 -p 0.3' returned non-zero exit status 134.
#   File "/tmp/ipykernel_2954464/516284570.py", line 5, in pri
#     if subprocess.check_call(command, cwd='/common/users/ac1771/imitation-game', shell=True):
#   File "/usr/lib/python3.8/subprocess.py", line 364, in check_call
#     raise CalledProcessError(retcode, cmd)
# subprocess.CalledProcessError: Command 'python3 src/main_nn.py -d 50 -w results/agent_1 -p 0.3' returned non-zero exit status 134.
# Process Process-7:
# Process Process-4:
# Process Process-1:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_2954464/516284570.py", line 5, in pri
#     if subprocess.check_call(command, cwd='/common/users/ac1771/imitation-game', shell=True):
#   File "/tmp/ipykernel_2954464/516284570.py", line 5, in pri
#     if subprocess.check_call(command, cwd='/common/users/ac1771/imitation-game', shell=True):
#   File "/usr/lib/python3.8/subprocess.py", line 364, in check_call
#     raise CalledProcessError(retcode, cmd)
#   File "/tmp/ipykernel_2954464/516284570.py", line 5, in pri
#     if subprocess.check_call(command, cwd='/common/users/ac1771/imitation-game', shell=True):
#   File "/usr/lib/python3.8/subprocess.py", line 364, in check_call
#     raise CalledProcessError(retcode, cmd)
#   File "/usr/lib/python3.8/subprocess.py", line 364, in check_call
#     raise CalledProcessError(retcode, cmd)
# subprocess.CalledProcessError: Command 'python3 src/main_nn.py -d 50 -w results/agent_1 -p 0.3' returned non-zero exit status 134.
# subprocess.CalledProcessError: Command 'python3 src/main_nn.py -d 50 -w results/agent_1 -p 0.3' returned non-zero exit status 134.
# subprocess.CalledProcessError: Command 'python3 src/main_nn.py -d 50 -w results/agent_1 -p 0.3' returned non-zero exit status 134.
# Aborted
# Aborted
# Aborted
# Aborted
# Aborted
# Aborted
# Aborted
# Aborted

# %%
# Create new threads
for i in range(5):
  t = myThread(i, "thread_{}".format(i), i)
  t.start()

print("Exiting Main Thread")

# %%
# measure probability calculation efficiency
results_df = pd.DataFrame(columns = ['Processed Cells', 'Retries', 'Time', 'Examinations', 'Movements', 'Actions', 'Terrain'])
agents = ["Agent 6", "Agent 7", "Agent 8"]

for x in range(100):
  command = 'python main.py -d 50 -p 0.3'
  out = json.loads(str(check_output(command, cwd='/Users/naveenanyogeswaran/Desktop/School/probabilistic-sensing/src', shell=True)).lstrip("b'").rstrip("'").replace("\\n", ""))

  for i,a in enumerate(agents):
    results_df = results_df.append([{'Agent': i+6, 'Processed Cells': out[a]["processed"], 'Retries': out[a]["retries"], 'Time': out[a]["time"], 'Examinations': out[a]["examinations"], 'Movements': out[a]["movements"], 'Actions': out[a]["examinations"] + out[a]["movements"], 'Terrain': out[a]["terrain"]}], ignore_index=True)

results_df.head()

# %%
path = 'results/agent_1/{}'.format('thread_test')
command = 'python3 src/main_nn.py -d 50 -w {} -p 0.3'.format(path)
subprocess.check_call(command, cwd='/common/users/ac1771/imitation-game', shell=True)

# %%
print(mp.cpu_count())
